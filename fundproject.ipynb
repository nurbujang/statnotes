# %% [markdown]
# # Fundamentals of Data Analysis Winter 2023 Project
#
# **Author: Nur Bujang**
#
# project.ipynb
# ***

# %% [markdown]
# # Project Instruction:
#
# > The project is to create a notebook investigating the variables and data points within the well-known iris flower data set associated with Ronald A Fisher.(1)
#
# > In the notebook, you should discuss the classification of each variable within the data set according to common variable types and scales of measurement in mathematics, statistics, and Python.
#
# > Select, demonstrate, and explain the most appropriate summary statistics to describe each variable.
#
# > Select, demonstrate, and explain the most appropriate plot(s) for each variable.
#
# > The notebook should follow a cohesive narrative about the data set.
#
# Deadline is Friday 22 December 2023.

# %% [markdown]
# # Project Title: Analysis Of The Iris Flower Dataset
#
# ## Abstract
#
# The goal of this project is to investigate the variables and data points within the *Iris* flower dataset. The Iris dataset contains 5 columns and 150 rows, consisting of 3 classes species with 50 lines each, with no missing values. Four attributes (length and width of petal of sepal) were used to morphologically determine whether an Iris is one of three species: *setosa*, *versicolor* or *virginica*.
#
# The significance of each variable classification in mathematics, statistics, and Python were discussed.
#
# Summary statistics were also discussed at length for each variable.
#
# Violin Plots and a Count Plot were the selected as the most appropriate plot for all numerical data  and categorical data, respectvely. Results from Violin Plots show that only petal length and width for Iris setosa are identifiably much smaller and can be differentiated from *Iris versicolor* and *Iris virginica*, while other attributes cannot significantly differentiate between *Iris* species. Results from Count Plot show 50 instances of each species in the dataset.
#
# This data can be used to develop Interactive Identification Keys for future botanists and researchers, as well as species determination using pattern recognition in Machine Learning.

# %% [markdown]
# ## 1.0 Background
#
# The problem of species differentiation within the *Iris* genus has long been discussed, especially between *I. versicolor* and *I. virginica* (Anderson, 1928, 1936). Molecular studies have been done to determine chromosomal numbers of different native and introduced Iris species as early as 1934 (Randolph, 1934).
#
# The Iris dataset was introduced by the British biologist and statistician Ronald A. Fisher in his paper to describe linear discriminant analysis published in 1936 (Wikipedia Contributors, 2019e). The flowers were collected from  Gaspé Peninsula in Canada (Anderson, 1935) and multiple locations from Central to Northern USA (Anderson, 1928, 1936). The dataset became famous because it provides a well-defined problem in the field of pattern recognition and machine learning and has become a reliable benchmark for testing and comparing different machine learning algorithms, particularly those involved in classification tasks (Lundy, 2023).
#
# In this genus, the color attribute is probably unreliable because of color polymorphism within the species or population. When coupled with phylogenetic studies which identifies the species and their closely-related species and common ancestors, it would become a powerful tool for taxonomists and researchers.

# %% [markdown]
# ## 2.0 Methods and Implementation

# %% [markdown]
# To begin, Python libraries numpy for computational operations and pandas for data loading and processing were imported. Other libraries were added and  described as the project progressed. Warning controls had to be issued to suppress warnings in the code (Docs.python.org, n.d., Deepak, 2023).

# %%
import numpy as np 
import os # to interact with the operating system
import pandas as pd 
import matplotlib.pyplot as plt 

import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

import warnings
warnings.filterwarnings('ignore') # to suppress warnings

# %% [markdown]
# The Iris dataset (iris.csv) was imported using os.path.join according to Pandas pydata read_csv (n.d.) and GeeksforGeeks (2019). Then, df.head (Pandas pydata df.head, n.d.) was performed to show the default first few lines of the dataframe.

# %%
file_path = os.path.join('~/Desktop/ATU/W23/FUNDAW2023/fundaw23', 'data', 'iris.csv')

df = pd.read_csv(file_path) # df contains iris.csv
df.head()  # default is 5
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   class
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# df.info was performed to provide a quick lookover of the dataset (The Pandas Development Team, 2022).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# The dataset iris.data contains 5 columns and 150 lines (replicates), consisting of 3 classes of 50 instances each, without missing values. The four attributes of a particular external flower structure (the length (in cm) and width (in cm) of the sepal and petal) are the independent variables used to determine or identify whether an Iris flower is one of three classes (*Iris setosa, I. versicolor or I. virginica*). in the dependent class column.
#
# ## 2.1 Classification of Variables
#
# ### 2.1.1 Feature Columns: 'sepal_length', 'sepal_width', 'petal_length' and 'petal_width'
#
# #### 2.1.1.1 float64
#
# From the output, the four independent columns are 64-bit floating-point numbers. These are also known as double precision floating-point, 64-bit IEEE-754 floating-point or double (Datacadamia - Data and Co, 2019). They occupy 64 bits in computer memory which allows large numbers to be stored (Wikipedia Contributors, 2019b). They use a floating radix point, which is a symbol that separates whole numbers or integers from fractions (Wikipedia Radix point, 2023).
#
# In mathematics, the 64-bit floating-point number represents real numbers with decimal points which provides high accuracy when performing calculations. While float64 is sufficient for most mathematical operations and storage, it has limitations in terms of accuracy due to rounding errors in infinitely large or small numbers (Beuzen, 2021). Some decimal numbers cannot be precisely represented in binary which leads to representation errors (Docs.python.org, n.d.). Higher precision formats such as 128-bit or 256-bit would remedy the problem to some extent, but even those would eventually reach their own limits.
#
# In statistics, 64-bit floating-point numbers are commonly used to represent continuous numerical data such as time, measurements and price. They are highly accurate and generally sufficient for statistical analysis and hypothesis testing. However, rounding errors would still apply when using float64, a finite value, to represent extremely small or large numbers.
#
# In computing, 64-bit floating-point numbers are used to represent real numbers in computing and are more space-efficient than higher precision formats such as 128-bit or 256-bit. A 64-bit floating-point number consists of a 1-bit sign, an 11-bit exponent, and a 52-bit fraction (Wikipedia Contributors, 2019b). It adheres to the IEEE 754 standard, which ensures powerful numerical computing, consistency and interoperability across different platforms and programming languages (ETHW, 2023).
#
# In Python, the float data type is typically implemented as a 64-bit floating-point number by default to represent real numbers. float64 provides a good balance between precision and performance in most applications, but it is not unlimited. Many Python applications follow the IEEE 754 specification (Camperbot, 2019), such as NumPy (Numpy.org constants, n.d.), thus allowing compatibility when performing mathematical and statistical operations.
#
# #### 2.1.1.2 Continuous Data
#
# Floating-point numbers are Continuous data types, which is a type of quantitative data (Pramoditha, 2020). These numeric values can take an infinite value within a certain range, which is different from discrete data which can only have distinct values (Zangre, 2023). These are measured in ratio scale, which has equal intervals between values and has a true zero point (web.pdx.edu, n.d.). Probability distributions can only apply on these numerical columns sepal_length, sepal_width, petal_length and petal_width.
#
# In mathematics, continuous data is fundamental to calculus (Wikipedia, 2020a). A real number is a number that can be used to quantify a one dimensional continuous amount (Wikipedia, 2020b). These real numbers are used as inputs in real functions (Wikipedia, 2022b), and according to Wikipedia Contributors (2019a), the general form of function is:
#
# ![Real Function](img/realfunction.png)
#
# where f is the name of the function, D is the domain of the function, and R is the codomain of the function, which is the set of real numbers.
#
# In statistics, continuous data often follows probability distributions and can be expressed as probability density functions  which describe all the possible values and the likelihood of these values occurring within a range (Wikipedia Contributors, 2019g). Continuous data is commonly used in regression analysis, which studies the relationship between one or more independent variables and a dependent variable, as well as predictive modeling (AVcontentteam, 2020). Continuous data also provides more accuracy in observations to make statistical inferences (Minitab Blog Editor, n.d.).
#
# In Python, libraries like NumPy (Numpy.org, n.d.) and Pandas (Pandas.pydata.org, n.d.) provide robust tools for working with continuous data (GeeksforGeeks, 2021a). Scikit-Learn provides tools for preprocessing, model training, and evaluation of models, often using continuous data in Python (Scikit-learn, 2019). The SciPy library in Python contains various statistical analysis and functions for various types of data, including continuous data (Scipy.org, 2019).
#
# ### 2.1.2 Target Column: 'class'
#
# #### 2.1.2.1 Object
#
# From the output, the column 'class' in the Iris dataset is an object.
#
# In mathematics and statistics, the object datatype allows representation of various categories and subcategories for mathematical operations and statistical analysis. These can include sets, numbers and functions, each with its own characteristic, behaviour, and mathematical representation (Wikipedia Contributors, 2019h).
#
# Python language is object-oriented In Python (W3Schools, 2019a) that utilises objects and classes (GeeksforGeeks, 2016). "Object datatype" generally refers to the generic object type, which can represent any Python object, such as numbers (int, float, complex), lists, dictionaries, strings and boolean (Soklaski, 2021, Sturtz, n.d.). These are types of classes which define a specific type of object (Silveira, 2022).
#
# #### 2.1.2.2 String
#
# Strings can be considered a form of categorical data type, particularly when they represent discrete categories or labels (Konkiewicz, 2020). Its main purpose is to store text (Wikipedia Contributors, 2018). In this Iris dataset, the objects are strings (setosa, virginica, versicolor), which is is a more specialized text data type compared to the generic object data type.
#
# In mathematics and statistics, strings are often used to represent categorical data. It allows for data representation and manipulation in mathematical functions and column labeling in datasets (GeeksforGeeks, 2022).
#
# In Python, string is used to store characters, usually text (Soklaski, 2021). According to Docs.python.org (n.d.), Python uses UTF-8 (Unicode Transformation Format, and 8-bit to encode) to represent various characters in string. It allows for data representation in a form of text which is crucial for various programming applications. Strings in Python are immutable, meaning once created, it becomes permanent (Google Developers, n.d.).
#
# #### 2.1.2.3 Nominal Categorical Data
#
#
# In this instance, it is a Categorical data type (non-numeric), which is a type of qualitative data, meaning it can only fall into a select group (Dettori and Norvell, 2018). It is a Nominal categorical variable, which is a type of categorical variable that represents categories or labels without specific order or ranking among them (Statistics Solutions, 2017). Because column 'class' is a nominal categorical variable, so no probability distributions are applicable.
#
# In mathematics, nominal categories are used in Set Theory to analyze union, intersections and difference among them (Wikipedia Contributors, 2019e).
#
# In statistics, nominal categorical data describes distinct qualities or groups within a dataset, such as gender, color and species. Analysis for nominal data includes Chi-Square Test of Goodness-of-Fit to assess the independence of nominal variables (McDonald, 2017) and Frequency Distribution which shows the observation count in each group (Wikipedia, 2022a).
#
# In Python, visualization libraries such as Matplotlib and Seaborn offer functions to generate plots for data exploration and visualisation of nominal categorical data, such as count plots (Waskom, 2012, Matplotlib.org, n.d.) and categorical scatter plots (Pydata.org, 2012). Also, Python's statistical libraries such as SciPy (Docs.scipy.org, n.d.) and StatsModels (www.statsmodels.org, n.d.) provide functions to test nominal variables.

# %% [markdown]
# ## 2.2 Summary Statistics
#
# Then, df.describe (Pandas.pydata.describe, n.d.) was executed for all columns to generate basic statistical information of each numeric column in the dataset, such as the mean and standard deviation to get a good overview of the distribution and central tendency of each variable in the iris dataset.
#
# Alternatively, df.describe can be called out separately for each numerical column.

# %%
df.describe() # OR:

# sepal_length_stats = df['sepal_length'].describe()
# print("Sepal Length Summary Statistics:\n", sepal_length_stats)

# sepal_depth_stats = df['sepal_depth'].describe()
# print("Sepal Length Summary Statistics:\n", sepal_depth_stats)

# petal_length_stats = df['petal_length'].describe()
# print("Sepal Length Summary Statistics:\n", petal_length_stats)

# petal_depth_stats = df['petal_depth'].describe()
# print("Sepal Length Summary Statistics:\n", petal_depth_stats)
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### 2.2.1 sepal_length
#
# #### 2.2.1.1 Count
#
# Count is the number of non-null (non-missing) values. Column sepal_length shows that it is complete with 150 values in 150 rows.
#
# Non-null values are important for accurate and meaningful data analysis and results because they provide a complete picture of the dataset. Both missing data and inputting missing data can cause bias or error in data analysis, thus leading to incorrect conclusions (www.linkedin.com, 2023a).
#
# In Python, non-null values are important to create an accurate visual representation to allow us to better visualise and understand patterns and trends. Some Python package, such as distfit does not handle missing values well and will produce error when it is run.
#
# In machine learning, missing values can create challenges during model training and prediction, because most algorithms require complete data for training (Rios et al., 2022). In the era of big data, the enormity and complexity of data have made it difficult for traditional machine learning methods to deal with missing data (Qiu et al., 2016). According to Emmanuel et al. (2021), there is no best method to impute data because the accuracy of machine learning imputation algorithm significantly depends on the data itself.
#
# #### 2.2.1.2 Mean
#
# Mean is the average value, which is a quick and easy way to summarize data. It provides a measure of central tendency, which pinpoints the middle position within the dataset (Laerd Statistics, 2018). It serves as a point of balance in a distribution, when the minimum and maximum values are equidistant from the mean (www.khanacademy.org, n.d.).
#
# According to StatisticsHowTo.com (n.d.), the formula for sample mean is:
#
# ![sample Mean](img/samplemean.png)
#
# where $\bar{x}$ is the sample mean, $\Sigma$ is the summation notation, x<sub>i</sub>​ is the observed values of a sample and n is the the number of observations.
#
# From the output, the mean for column sepal_length is **5.84mm** with the range between 4.30mm to 7.90mm. It is considered a sample mean, and not a population mean, because it is a measurement of a representative subset of a small number of the population (Ravikiran, 2021).
#
# Because outliers will distort the mean, mean is used when the variable is not skewed, or when the data is nominal (Laerd Statistics, 2018). Mean values are used in various statistical formulas, including variance, standard deviation, and correlation.
#
# #### 2.2.1.3 Std (Standard Deviation)
#
# According to Wikipedia Contributors (2019j), standard deviation is how far the data is spread around the mean, with low value indicating that data is concentrated close to the mean and high value indicating that data is spread out. The empirical rule 68–95–99.7 in a Normal distribution states that 68%, 95%, and 99.7% of the data fall within one, two and three standard deviation of the mean, respectively. The standard deviation for sepal_length is **0.83mm**, suggesting that data is clustered close to the mean.
#
# According to www.ncl.ac.uk (n.d.), the Sample Standard Deviation formula is:
#
# ![Sample Standard Deviation](img/samplestd.png)
#
# where s is sample standard deviation, $\Sigma$ is the summation notation, x<sub>i</sub>​ is the observed values of a sample, $\bar{x}$ is the sample mean, and N is the the number of observations.
#
# Standard deviation is used to assess the variability of features in predictive models in machine learning (Austin et al., 2016).
#
# #### 2.2.1.4 Min
#
# Min is the smallest value in a dataset. The lowest value observed for sepal_length is **4.3mm**.
#
# It provides information about the lower end of the data distribution in range calculation to see the spread of the data. This extremely low value could possibly indicate that it is an outlier if it falls outside an expected limit (Cowley, 2021). When plotting data for data visualisation, the smallest value helps set the scales on the plot to ensure that all are represented.
#
# #### 2.2.1.5 25% Quartile
#
# Quartiles divide the data into four equal parts. According to Wikipedia (2021), 25% of data lies below the first/lower quartile (Q<sub>1</sub>), 50% of data lies below the second quartile (Q<sub>2</sub>) and 75% of data lies below the the third/upper quartile (Q<sub>3</sub>). From a statistical standpoint, it indicates the spread of the data, presence of outliers and whether it is skewed or symmetrical (Wikipedia, 2021).
#
# The lower quartile for column sepal_length is **5.1mm**. Because 25th percentile describes the spread of the lower portion of a dataset, this means that 25% of the data is below 5.1mm, while the rest of the data (the highest 75%) is above 5.1mm. If the lower quartile is farther from the median than the upper quartile, this indicates a negatively-skewed distribution or left-skewed, where the smaller values are more dispersed with a longer tail and the larger values are more concentrated on the right (Taylor, 2022a, Turney, 2022). Also, if a data point falls significantly below this first quartile, it may be a potential outlier.
#
# The distance between the lower quartile and the median is 0.7mm, which is more than the distance between the upper quartile and the median (0.6mm), suggesting that it is negatively-skewed (left-skewed).
#
# #### 2.2.1.6 50% Quartile (median)
#
# The median is the measure of tendency that splits a dataset into two equal parts (lower and upper) when data is arranged from lowest to highest (Liberto, 2019). The median is less sensitive to extreme values (outliers) than the mean (Australian Bureau of Statistics, 2023).
#
# The median is used when the variable is ordinal or skewed (Laerd Statistics, 2018). As the difference between the median and mean increases, the more skewed the distribution becomes, and in such situation, the use of median is preferred (Laerd Statistics, 2018).
#
# According to LibreTexts Statistics (2019) and Wikipedia Contributors (2019i), a perfectly symmetrical distribution would have the same mean, median and mode values. The median for column sepal_length is **5.8mm**, which is smaller than the mean (5.84mm), however, according to Wikipedia Contributors (2019i), value comparison between mean and median is irrelevant to skewness, where both negative and positive skews can have its mean bigger or smaller than the median.
#
# #### 2.2.1.7 75% Quartile
#
# The 75th percentile describes the spread of the upper portion of a dataset. The upper quartile for sepal_length is **6.4mm**. Because the 75% Quartile separates the highest 25% of data from the lowest 75%, this means that 75% of the data is below 6.4mm, while the rest of the data (the highest 25%) is above 6.4mm.
#
# If the upper quartile is farther from the median than the lower quartile, this indicates a positively-skewed distribution or right-skewed, where the bigger values are more dispersed with a longer tail and the smaller values are more clustered on the left (Taylor, 2022b, Turney, 2022). Also, if a data point reaches significantly above this third quartile, it may be a potential outlier.
#
# The distance between the upper quartile and the median is 0.6mm, which is less than the 25% Quartile (0.7mm), thus indicating that it is left-skewed.
#
# #### 2.2.1.8 Max
#
# Max is the largest value in a dataset. The maximum value observed for sepal_length is **7.9mm**.
#
# In range calculation, it provides information about the upper end of the data distribution to see the spread of the data. This extremely high value could possibly indicate that it is an outlier if it falls outside a valid range (Cowley, 2021). When plotting data, the maximum value helps to set the appropriate scales on the plot to ensure that all are accurately represented for data visualisation.
#
# ### 2.2.2 sepal_width
#
# #### 2.2.2.1 Count
#
# Column sepal_width shows that it is complete with 150 values in 150 rows.
#
# #### 2.2.2.2 Mean
#
# From the output, the mean for column sepal_width is **3.05mm** with the range between 2.0mm to 4.4mm.
#
# #### 2.2.2.3 Std (Standard Deviation)
#
# The standard deviation for sepal_width is **0.43mm**, suggesting that data is accumulated close around the mean.
#
# #### 2.2.2.4 Min
#
# The minimum value observed for sepal_width is **2.0mm**.
#
# #### 2.2.2.5 25% Quartile
#
# The lower quartile for column sepal_width is **2.8mm**, meaning 25% of the data is below 2.8mm, while the rest of the data (the highest 75%) is above that.
#
# The distance between the lower quartile and the median is 0.2mm, which is lower than the distance between the upper quartile and the median (0.3mm), which indicates a right skew.
#
# #### 2.2.2.6 50% Quartile (median)
#
# The median for column sepal_width is **3.0mm**.
#
# #### 2.2.2.7 75% Quartile
#
# The upper quartile for sepal_width is **3.3mm**, meaning that 75% of the data is below 3.3mm, while the rest of the data (the highest 25%) is above that.
#
# The distance between the upper quartile and the median is 0.3mm, which is higher than the distance between the lower quartile and the median (0.2mm). This indicates a right skew distribution.
#
# #### 2.2.2.8 Max
#
# The maximum value observed for sepal_width is **4.4mm**.
#
# ### 2.2.3 petal_length
#
# #### 2.2.3.1 Count
#
# Column petal_length shows that it is complete with 150 values in 150 rows.
#
# #### 2.2.3.2 Mean
#
# The mean for column petal_length is **3.76mm** with a big range between 1.0mm to 6.9mm.
#
# #### 2.2.3.3 Std (Standard Deviation)
#
# The standard deviation for petal_length is **1.76mm**, suggesting that data is more spread out over a wide range.
#
# #### 2.2.3.4 Min
#
# The minimum value observed for petal_length is **1.0mm**.
#
# #### 2.2.3.5 25% Quartile
#
# The lower quartile for column petal_length is **1.6mm**. This means that 25% of the data is below 1.6mm, while the rest of the data is above 1.6mm.
#
# The distance between the lower quartile and the median is 2.75mm, which is more than the distance between the upper quartile and the median (0.3mm), which indicates a left skew.
#
# #### 2.2.3.6 50% Quartile (median)
#
# The median for column petal_length is **4.35mm**.
#
# #### 2.2.3.7 75% Quartile
#
# The upper quartile for petal_length is **5.1mm**, which means 75% of the data is below 5.1mm, while the highest 25% is above 5.1mm.
#
# The distance between the upper quartile and the median is 0.75mm, which is less than the distance between the lower quartile and the median (2.75mm). This indicates a left skew.
#
# #### 2.2.3.8 Max
#
# The maximum value observed for petal_length is **6.9mm**.
#
# ### 2.2.4 petal_width
#
# #### 2.2.4.1 Count
#
# Column petal_width shows that it is complete with 150 values in 150 rows.
#
# #### 2.2.4.2 Mean
#
# The mean for column petal_width is **1.20mm** with the range between 0.1mm to 2.50mm.
#
# #### 2.2.4.3 Std (Standard Deviation)
#
# The standard deviation for petal_width is **0.76mm**. Considering the mean is only 1.20mm, the standard deviation suggests that data for petal_with is extremely spread out.
#
# #### 2.2.4.4 Min
#
# The minimum value observed for petal_width is **0.1mm**, which is extremely small. One could argue that this is an outlier or simply human error.
#
# ##### 2.2.4.4.1 Outliers
#
# According to Engineering Statistics Handbook (2019), outliers are observations that stand out because they are abnormally far from the rest of the data in a dataset. Outliers can potentially skew statistical analyses and key statistical calculations such as mean and standard deviation are particularly susceptible to it. Choosing the appropriate methods for outlier detection and treatment depends on the data itself and the objectives of the analysis (www.linkedin.com, 2023b).
#
# ##### 2.2.4.4.2 Human Error
#
# According to Wikipedia Contributors (2019d), human error is an accidental action or oversight that leads to extreme values that deviate from acceptable limits. In statistics and Python, it is a serious mistake that compromises result accuracy and analysis validity, thus causing flawed conclusions and unreliable applications. Examples of human error include data collection error, data entry error and human bias. These can be easily identified as points that lie far from the main cluster when data is plotted.
#
# #### 2.2.4.5 25% Quartile
#
# The lower quartile for column petal_width is **0.3mm**, meaning that 25% of the data is below 0.3mm, while the rest of the data is above that.
#
# The distance between the lower quartile and the median is 1.0mm, which is higher than the distance between the upper quartile and the median (0.5mm). This indicates a left skew, where more data are clustered on the right side.
#
# #### 2.2.4.6 50% Quartile (median)
#
# The median for column petal_width is **1.3mm**.
#
# #### 2.2.1.7 75% Quartile
#
# The upper quartile for petal_width is **1.8mm**, meaning that 75% of the data is below 1.8mm, while the highest 25% is above that.
#
# The distance between the upper quartile and the median is 0.5mm, which is lower than the distance between the lower quartile and the median (0.2mm). This indicates a left skew distribution.
#
# #### 2.2.1.8 Max
#
# The maximum value observed for petal_width is **2.5mm**.

# %% [markdown]
# ## 2.3 Plots
#
# ### 2.3.1 Violin Plot for Numerical Data
#
# While a histogram (Wikipedia Contributors, 2019c) with Kernel Density Estimation (KDE) (Wikipedia Contributors, 2019f) is an appropriate plot for each numerical variable, it lumps the observation for all three Iris species together, making it less useful for data interpretation. Therefore, the most appropriate plot which also groups Iris species separately for each flower attribute and provides the most statistical information and data distribution is the Violin Plot.
#
# The Violin plot is hybrid of a box plot and a kernel density plot and it compares probability distributions between two variables (Wikipedia, 2020c, Seaborn.pydata.org violinplot, n.d.). The Violin curve's width indicates frequency in each section and is computed using KDE (Yi, 2021). While the box plot only outlines the summary statistics (Carron, 2021), the Violin Plot shows both the summary statistics and each variable's density, thus offering a more detailed representation of the shape of the data.
#
# Violin Plots with clearer overlapping boxplots were generated for all numerical columns according to C (2021). To optimise spacing between subplots, fig.tight_layout was used according to GeeksforGeeks spacing (2020). Spacing between subplots and title (y=1.01) were adjusted according to Ceylan (2018).

# %%
columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']

fig, axs = plt.subplots(1, len(columns)-1, figsize=(20,6)) #
for i in range(0,len(columns)-1): 
    ax=sns.violinplot(x='class', y=df[columns[i]], data=df, ax=axs[i])
    sns.boxplot(x='class', y=df[columns[i]], data=df, palette='turbo', width=0.12,
            boxprops={'zorder': 2}, ax=ax)
    axs[i].set_ylabel(columns[i])

plt.suptitle('Violin Plot for Sepal and Petal Attributes of Three Iris species', color='#3D3F38', 
             fontweight='bold', size=15) 
fig.tight_layout()
plt.show();

# %% [markdown]
# The Violin Plot shows that in general, petal length and width for *I. setosa* are identifiably much smaller than *I.versicolor* and *I.virginica*, but it is not significantly different in terms of sepal attributes. *I. versicolor* and *I. virginica* are not significantly different in all petal and sepal attributes.
#
# For sepal length, *I. setosa* has a higher density of data around the median and is symmetrically distributed. Observations in *I. versicolor* and virginica are more wide-spread and right-skewed.
#
# For sepal width, all three species are not significantly different from one another with higher accumulation of data around the median. *I. setosa* has long tails on both lower and upper ends, suggesting a wide range. *I. versicolor* is negatively-skewed and there are outliers present on the lower and upper ends of *I. virginica*.
#
# For petal length, while it is symmetrically distributed with a big cluster of data around the median, outliers are also present on both lower and upper ends of *I. setosa*. *I. versicolor* and *I. virginica* data are more dispersed but slightly left-skewed.
#
# Interestingly, for petal_width in *I. setosa*, the min value is the same as the first quartile, meaning that the data distribution is relatively concentrated above this minimum value and right-skewed. Outliers are also present above the upper end. Data is more spread out in *I. versicolor* and *I. virginica* and both are also positively skewed.

# %% [markdown]
# ### 2.3.2 Count Plots for Categorical Data
#
# The Count Plot was selected as the most appropriate plot for the categorical variable. This was generated using seaborn countplot (Waskom, 2012), colour-customised to pastel pallette according to GeeksforGeeks (2021b) with added edgecolor as shown in Datavizpyr (2021).

# %%
sns.countplot(x='class', data=df, palette="pastel", edgecolor="black")
plt.title('Distribution of Species in Iris Dataset', fontweight='bold', size=17, y=1.1)
plt.show()

# %% [markdown]
# Count plot shows that there are 50 replicates/instances of each *Iris *species in the dataset.

# %% [markdown]
# ## 3.0 Conclusion
#
# The classification and summary statistics were discussed in depth for each variable.
#
# Violin Plots were the selected as the most appropriate plot for all numerical data, while a Count Plot was selected as the most appropriate plot for categorical data. Results from Violin Plots show that only petal length and width for I. setosa are distinctly smaller than *I. versicolor* and *I. virginica*, while other attributes cannot significantly differentiate between the *Iris* species. Results from Count Plot show 50 instances of each species in the dataset.

# %% [markdown]
# ## 4.0 References

# %% [markdown]
# Anderson, E. (1928). The Problem of Species in the Northern Blue Flags, Iris versicolor L. and Iris virginica L. Annals of the Missouri Botanical Garden, 15(3), p.241. doi:https://doi.org/10.2307/2394087.
#
# Anderson, E. (1935). The irises of the Gaspe Peninsula. Bulletin of the American Iris Society, 59, pp.2–5.
#
# Anderson, E. (1936). The Species Problem in Iris. Annals of the Missouri Botanical Garden, 23(3), p.457. doi:https://doi.org/10.2307/2394164.archive.ics.uci.edu. (1988). UCI Machine Learning Repository. [online] Available at: https://archive.ics.uci.edu/dataset/53/iris [Accessed 14 Oct. 2023].
#
# Austin, B., French, B., Adesope, O. and Gotch, C. (2016). Use of Standard Deviations as Predictors in Models Using Large-Scale International Data Sets. The Journal of Experimental Education, 85(4), pp.559–573. doi:https://doi.org/10.1080/00220973.2016.1260522.
#
# Australian Bureau of Statistics (2023). Measures of central tendency | Australian Bureau of Statistics. [online] www.abs.gov.au. Available at: https://www.abs.gov.au/statistics/understanding-statistics/statistical-terms-and-concepts/measures-central-tendency [Accessed 8 Dec. 2023].
#
# AVcontentteam (2020). 8 Ways to deal with Continuous Variables in Predictive Modeling. [online] Analytics Vidhya. Available at: https://www.analyticsvidhya.com/blog/2015/11/8-ways-deal-continuous-variables-predictive-modeling/ [Accessed 4 Dec. 2023].
#
# Beuzen, T. (2021). Floating point numbers and rounding errors - a crash course in Python. [online] Tomas Beuzen. Available at: https://www.tomasbeuzen.com/post/floating-point-numbers/ [Accessed 4 Dec. 2023].
#
# C, J. (2021). How to display boxplot in front of violinplot in seaborn - seaborn zorder? [online] Stack Overflow. Available at: https://stackoverflow.com/questions/68614447/how-to-display-boxplot-in-front-of-violinplot-in-seaborn-seaborn-zorder [Accessed 8 Dec. 2023].
#
# Camperbot (2019). How to use Python Floating Point Numbers - Explained with Examples. [online] The freeCodeCamp Forum. Available at: https://forum.freecodecamp.org/t/how-to-use-python-floating-point-numbers-explained-with-examples/19214 [Accessed 4 Dec. 2023].
#
# Carron, J. (2021). Violin Plots 101: Visualizing Distribution and Probability Density | Mode. [online] mode.com. Available at: https://mode.com/blog/violin-plot-examples [Accessed 8 Dec. 2023].
#
# Cowley, O. (2021). Maximums, Minimums & Outliers in a Data Set - Video & Lesson Transcript | Study.com. [online] Study.com. Available at: https://study.com/academy/lesson/maximums-minimums-outliers-in-a-data-set-lesson-quiz.html [Accessed 8 Dec. 2023].
#
# Datacadamia - Data and Co. (2019). Computer Number - Float64 (64-bit or double precision) floating-p ... [online] Available at: https://datacadamia.com/data/type/number/computer/float64 [Accessed 4 Dec. 2023].
#
# Datavizpyr (2021). How To Change Edge Color on Seaborn Scatter Plot? - Data Viz with Python and R. [online] datavizpyr.com. Available at: https://datavizpyr.com/change-edge-color-on-seaborn-scatter-plot/ [Accessed 6 Dec. 2023].
#
# Deepak (2023). [With Example] Ignore warnings python with Filter. [online] QuizCure.com. Available at: https://www.quizcure.com/python/ignore-warnings-using-filter-examples [Accessed 3 Dec. 2023].
#
# Dettori, J.R. and Norvell, D.C. (2018). The Anatomy of Data. Global Spine Journal , [online] 8(3), pp.311–313. doi:https://doi.org/10.1177/2192568217746998.
#
# Docs.python.org. (n.d.). 15. Floating Point Arithmetic: Issues and Limitations — Python 3.10.1 documentation. [online] Available at: https://docs.python.org/3/tutorial/floatingpoint.html [Accessed 4 Dec. 2023].
#
# Docs.python.org. (n.d.). Unicode HOWTO — Python 3.10.0 documentation. [online] Available at: https://docs.python.org/3/howto/unicode.html [Accessed 4 Dec. 2023].
#
# Docs.python.org. (n.d.). warnings — Warning control — Python 3.8.5 documentation. [online] Available at: https://docs.python.org/3/library/warnings.html [Accessed 3 Dec. 2023].
#
# Docs.scipy.org. (n.d.). scipy.stats.contingency.association — SciPy v1.11.4 Manual. [online] Available at: https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html [Accessed 5 Dec. 2023].
#
# Emmanuel, T., Maupong, T., Mpoeleng, D., Semong, T., Mphago, B. and Tabona, O. (2021). A survey on missing data in machine learning. Journal of Big Data, 8(1). doi:https://doi.org/10.1186/s40537-021-00516-9.Engineering Statistics Handbook (2019). What are outliers in the data? [online] Nist.gov. Available at: https://www.itl.nist.gov/div898/handbook/prc/section1/prc16.htm [Accessed 7 Dec. 2023].
#
# ETHW. (2023). Milestones:IEEE Standard 754 for Binary Floating-Point Arithmetic, 1985. [online] Available at: https://ethw.org/Milestones:IEEE_Standard_754_for_Binary_Floating-Point_Arithmetic,_1985 [Accessed 4 Dec. 2023].
#
# GeeksforGeeks spacing. (2020). How to set the spacing between subplots in Matplotlib in Python? [online] Available at: https://www.geeksforgeeks.org/how-to-set-the-spacing-between-subplots-in-matplotlib-in-python/ [Accessed 3 Dec. 2023].
#
# GeeksforGeeks. (2016). Python OOPs Concepts. [online] Available at: https://www.geeksforgeeks.org/python-oops-concepts/ [Accessed 4 Dec. 2023].
#
# GeeksforGeeks. (2019). Python | os.path.join() method. [online] Available at: https://www.geeksforgeeks.org/python-os-path-join-method/ [Accessed 7 Dec. 2023].
#
# GeeksforGeeks. (2021a). Pandas Cut - Continuous to Categorical. [online] Available at: https://www.geeksforgeeks.org/pandas-cut-continuous-to-categorical/ [Accessed 4 Dec. 2023].
#
# GeeksforGeeks. (2021b). Seaborn - Color Palette. [online] Available at: https://www.geeksforgeeks.org/seaborn-color-palette/ [Accessed 6 Dec. 2023].
#
# GeeksforGeeks. (2022). Introduction to Strings - Data Structure and Algorithm Tutorials. [online] Available at: https://www.geeksforgeeks.org/introduction-to-strings-data-structure-and-algorithm-tutorials/ [Accessed 5 Dec. 2023].Google Developers. (n.d.). Python Strings | Python Education. [online] Available at: https://developers.google.com/edu/python/strings [Accessed 5 Dec. 2023].
#
# Konkiewicz, M. (2020). What are categorical variables and how to encode them? [online] Google.com. Available at: https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=&ved=2ahUKEwjk79C4k_OCAxWVUUEAHXarB-UQFnoECDMQAQ&url=https%3A%2F%2Fwww.aboutdatablog.com%2Fpost%2Fwhat-are-categorical-variables-and-how-to-encode-them&usg=AOvVaw1BoVgNG2an8NjNRf4PMG3x&opi=89978449 [Accessed 3 Dec. 2023].
#
# Laerd Statistics (2018). Measures of Central Tendency. [online] Laerd.com. Available at: https://statistics.laerd.com/statistical-guides/measures-central-tendency-mean-mode-median.php [Accessed 7 Dec. 2023].
#
# Liberto, D. (2019). Quartile Definition. [online] Investopedia. Available at: https://www.investopedia.com/terms/q/quartile.asp [Accessed 8 Dec. 2023].
#
# LibreTexts Statistics . (2019). 2.6: Skewness and the Mean, Median, and Mode. [online] Available at: https://stats.libretexts.org/Bookshelves/Applied_Statistics/Introductory_Business_Statistics_(OpenStax)/02%3A_Descriptive_Statistics/2.06%3A_Skewness_and_the_Mean_Median_and_Mode [Accessed 8 Dec. 2023].
#
# Lundy, D. (2023). Mastering Machine Learning: Exploring the IRIS Dataset for Predictive Analysis. [online] Medium. Available at: https://medium.com/@daniel.lundy.analyst/mastering-machine-learning-exploring-the-iris-dataset-for-predictive-analysis-f52a76bd7075 [Accessed 3 Dec. 2023].
#
# Matplotlib.org. (n.d.). Plotting categorical variables — Matplotlib 3.8.2 documentation. [online] Available at: https://matplotlib.org/stable/gallery/lines_bars_and_markers/categorical_variables.html [Accessed 5 Dec. 2023].
#
# McDonald, J.H. (2017). 2: Tests for Nominal Variables. [online] Statistics LibreTexts. Available at: https://stats.libretexts.org/Bookshelves/Applied_Statistics/Biological_Statistics_(McDonald)/02%3A_Tests_for_Nominal_Variables [Accessed 5 Dec. 2023].
#
# Minitab Blog Editor (n.d.). Why Is Continuous Data ‘Better’ than Categorical or Discrete Data? [online] blog.minitab.com. Available at: https://blog.minitab.com/en/understanding-statistics/why-is-continuous-data-better-than-categorical-or-discrete-data [Accessed 4 Dec. 2023].
#
# Numpy.org constants. (n.d.). Constants — NumPy v1.24 Manual. [online] Available at: https://numpy.org/doc/stable/reference/constants.html [Accessed 4 Dec. 2023].
#
# Numpy.org. (n.d.). NumPy: the absolute basics for beginners — NumPy v1.19.dev0 Manual. [online] Available at: https://numpy.org/devdocs/user/absolute_beginners.html [Accessed 4 Dec. 2023].
#
# Pandas pydata df.head (n.d.). pandas.DataFrame.head — pandas 1.3.4 documentation. [online] pandas.pydata.org. Available at: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html [Accessed 3 Dec. 2023].
#
# Pandas pydata read_csv (n.d.). pandas.read_csv — Pandas 1.2.4 Documentation. [online] pandas.pydata.org. Available at: https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html [Accessed 3 Dec. 2023].
#
# Pandas.pydata.describe. (n.d.). pandas.DataFrame.describe — pandas 1.3.4 documentation. [online] Available at: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html [Accessed 3 Dec. 2023].
#
# Pandas.pydata.org. (n.d.). pandas.cut — pandas 0.23.1 documentation. [online] Available at: https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.cut.html [Accessed 4 Dec. 2023].
#
# Pramoditha, R. (2020). pandas for Data Science: Part 2. [online] Data Science 365. Available at: https://medium.com/data-science-365/pandas-for-data-science-part-2-c12c3ee876c2 [Accessed 3 Dec. 2023].
#
# Pydata.org. (2012). Plotting with categorical data — seaborn 0.9.0 documentation. [online] Available at: https://seaborn.pydata.org/tutorial/categorical.html [Accessed 5 Dec. 2023].
#
# Qiu, J., Wu, Q., Ding, G., Xu, Y. and Feng, S. (2016). A survey of machine learning for big data processing. EURASIP Journal on Advances in Signal Processing, 2016(1). doi:https://doi.org/10.1186/s13634-016-0355-x.
#
# Randolph, L.F. (1934). Chromosome numbers in native American and introduced species and cultivated varieties of Iris. Bulletin of the American Iris Society, 52, pp.61–66.
#
# Ravikiran, A.S. (2021). Population vs Sample: Definitions, and Differences. [online] Simplilearn.com. Available at: https://www.simplilearn.com/tutorials/machine-learning-tutorial/population-vs-sample [Accessed 7 Dec. 2023].
#
# Rios, R., Miller, R.J.H., Manral, N., Sharir, T., Einstein, A.J., Fish, M.B., Ruddy, T.D., Kaufmann, P.A., Sinusas, A.J., Miller, E.J., Bateman, T.M., Dorbala, S., Di Carli, M., Van Kriekinge, S.D., Kavanagh, P.B., Parekh, T., Liang, J.X., Dey, D., Berman, D.S. and Slomka, P.J. (2022). Handling missing values in machine learning to predict patient-specific risk of adverse cardiac events: Insights from REFINE SPECT registry. Computers in Biology and Medicine, 145, p.105449. doi:https://doi.org/10.1016/j.compbiomed.2022.105449.Scikit-learn (2019). scikit-learn: machine learning in Python. [online] Scikit-learn.org. Available at: https://scikit-learn.org/stable/ [Accessed 4 Dec. 2023].
#
# Scipy.org. (2019). Statistical functions (scipy.stats) — SciPy v1.3.3 Reference Guide. [online] Available at: https://docs.scipy.org/doc/scipy/reference/stats.html [Accessed 4 Dec. 2023].
#
# Seaborn.pydata.org violinplot. (n.d.). seaborn.violinplot — seaborn 0.10.1 documentation. [online] Available at: https://seaborn.pydata.org/generated/seaborn.violinplot.html [Accessed 8 Dec. 2023].
#
# Silveira, O.S. (2022). Data Types in Python (A Simple Beginner’s Guide). [online] Dataquest. Available at: https://www.dataquest.io/blog/data-types-in-python/ [Accessed 4 Dec. 2023].
#
# Soklaski, R. (2021). Basic Object Types — Python Like You Mean It. [online] www.pythonlikeyoumeanit.com. Available at: https://www.pythonlikeyoumeanit.com/Module2_EssentialsOfPython/Basic_Objects.html [Accessed 4 Dec. 2023].
#
# Statistics Solutions. (2017). Levels of Measurement. [online] Available at: https://www.statisticssolutions.com/levels-of-measurement/ [Accessed 3 Dec. 2023].
#
# StatisticsHowTo.com (n.d.). Sample Mean: Symbol (X Bar), Definition, Standard Error. [online] Statistics How To. Available at: https://www.statisticshowto.com/probability-and-statistics/statistics-definitions/sample-mean/ [Accessed 7 Dec. 2023].
#
# Sturtz, J. (n.d.). Basic Data Types in Python – Real Python. [online] realpython.com. Available at: https://realpython.com/python-data-types/ [Accessed 5 Dec. 2023].
#
# Taylor, S. (2022a). Negatively Skewed Distribution. [online] Corporate Finance Institute. Available at: https://corporatefinanceinstitute.com/resources/data-science/negatively-skewed-distribution/ [Accessed 8 Dec. 2023].
#
# Taylor, S. (2022b). Positively Skewed Distribution. [online] Corporate Finance Institute. Available at: https://corporatefinanceinstitute.com/resources/data-science/positively-skewed-distribution/ [Accessed 8 Dec. 2023].
#
# The Pandas Development Team (2022). pandas.DataFrame.info — pandas 1.4.1 documentation. [online] pandas.pydata.org. Available at: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html [Accessed 3 Dec. 2023].
#
# Turney, S. (2022). Quartiles & Quantiles | Definition, Calculation & Interpretation. [online] Scribbr. Available at: https://www.scribbr.com/statistics/quartiles-quantiles/ [Accessed 8 Dec. 2023].
#
# W3Schools (2019a). Python Classes. [online] W3schools.com. Available at: https://www.w3schools.com/python/python_classes.asp [Accessed 4 Dec. 2023].
#
# W3Schools (2019b). Python For Loops. [online] W3schools.com. Available at: https://www.w3schools.com/python/python_for_loops.asp [Accessed 22 Oct. 2023].
#
# Waskom, M. (2012). seaborn.countplot — seaborn 0.9.0 documentation. [online] Pydata.org. Available at: https://seaborn.pydata.org/generated/seaborn.countplot.html [Accessed 3 Dec. 2023].
#
# Waskom, M. (2022). seaborn-data. [online] GitHub. Available at: https://github.com/mwaskom/seaborn-data/blob/master/penguins.csv [Accessed 13 Oct. 2023].
#
# web.pdx.edu. (n.d.). lecture1 Types of scales & levels of measurement. [online] Available at: https://web.pdx.edu/~newsomj/pa551/lecture1.htm [Accessed 3 Dec. 2023].
#
# Wikipedia Contributors (2018). String (computer science). [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/String_(computer_science) [Accessed 5 Dec. 2023].
#
# Wikipedia Contributors (2019a). Continuous function. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Continuous_function [Accessed 4 Dec. 2023].
#
# Wikipedia Contributors (2019b). Double-precision floating-point format. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Double-precision_floating-point_format [Accessed 4 Dec. 2023].
#
# Wikipedia Contributors (2019c). Histogram. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Histogram [Accessed 6 Dec. 2023].
#
# Wikipedia Contributors (2019d). Human error. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Human_error [Accessed 7 Dec. 2023].
#
# Wikipedia Contributors (2019e). Iris flower data set. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Iris_flower_data_set [Accessed 2 Dec. 2023].
#
# Wikipedia Contributors (2019f). Kernel density estimation. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Kernel_density_estimation [Accessed 6 Dec. 2023].
#
# Wikipedia Contributors (2019g). Probability density function. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Probability_density_function [Accessed 4 Dec. 2023].
#
# Wikipedia Contributors (2019h). Set theory. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Set_theory [Accessed 5 Dec. 2023].
#
# Wikipedia Contributors (2019i). Skewness. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Skewness [Accessed 8 Dec. 2023].
#
# Wikipedia Contributors (2019j). Standard deviation. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/Standard_deviation [Accessed 7 Dec. 2023].
#
# Wikipedia Contributors (2020). 68–95–99.7 rule. [online] Wikipedia. Available at: https://en.wikipedia.org/wiki/68%E2%80%9395%E2%80%9399.7_rule [Accessed 7 Dec. 2023].
#
# Wikipedia Radix point. (2023). Radix point. [online] Available at: https://simple.wikipedia.org/wiki/Radix_point [Accessed 4 Dec. 2023].
#
# Wikipedia. (2020a). Continuous or discrete variable. [online] Available at: https://en.wikipedia.org/wiki/Continuous_or_discrete_variable [Accessed 4 Dec. 2023].
#
# Wikipedia. (2020b). Real number. [online] Available at: https://en.wikipedia.org/wiki/Real_number [Accessed 4 Dec. 2023].
#
# Wikipedia. (2020c). Violin plot. [online] Available at: https://en.wikipedia.org/wiki/Violin_plot [Accessed 8 Dec. 2023].
#
# Wikipedia. (2021). Quartile. [online] Available at: https://en.wikipedia.org/wiki/Quartile [Accessed 8 Dec. 2023].
#
# Wikipedia. (2022a). Frequency distribution. [online] Available at: https://simple.wikipedia.org/wiki/Frequency_distribution [Accessed 5 Dec. 2023].
#
# Wikipedia. (2022b). Function of a real variable. [online] Available at: https://en.wikipedia.org/wiki/Function_of_a_real_variable [Accessed 4 Dec. 2023].
#
# Wikipedia. (2023). Mathematical object. [online] Available at: https://en.wikipedia.org/wiki/Mathematical_object [Accessed 4 Dec. 2023].
#
# www.khanacademy.org. (n.d.). Mean as the balancing point. [online] Available at: https://www.khanacademy.org/math/cc-sixth-grade-math/cc-6th-data-statistics/cc-6th-mean-median-challenge/a/mean-as-the-balancing-point [Accessed 7 Dec. 2023].
#
# www.linkedin.com. (2023a). How do you avoid introducing bias or error when inputing missing data? [online] Available at: https://www.linkedin.com/advice/3/how-do-you-avoid-introducing-bias-error-when-inputing [Accessed 7 Dec. 2023].
#
# www.linkedin.com. (2023b). How do you handle outliers when performing feature selection? [online] Available at: https://www.linkedin.com/advice/1/how-do-you-handle-outliers-when-performing-feature [Accessed 7 Dec. 2023].
#
# www.ncl.ac.uk. (n.d.). Numeracy, Maths and Statistics - Academic Skills Kit. [online] Available at: https://www.ncl.ac.uk/webtemplate/ask-assets/external/maths-resources/statistics/descriptive-statistics/variance-and-standard-deviation.html [Accessed 7 Dec. 2023].
#
# www.statsmodels.org. (n.d.). Contingency tables - statsmodels 0.14.0. [online] Available at: https://www.statsmodels.org/stable/contingency_tables.html [Accessed 5 Dec. 2023].
#
# www.w3schools.com. (n.d.). Python isinstance() Function. [online] Available at: https://www.w3schools.com/python/ref_func_isinstance.asp [Accessed 22 Oct. 2023].
#
# Yi, M. (2021). A Complete Guide to Violin Plots. [online] Chartio. Available at: https://chartio.com/learn/charts/violin-plot-complete-guide/ [Accessed 8 Dec. 2023].
#
# Zangre, A. (2023). Discrete vs. Continuous Data: What’s the Difference? [online] g2.com. Available at: https://www.g2.com/articles/discrete-vs-continuous-data [Accessed 4 Dec. 2023].

# %% [markdown]
# ***
#
# ## End
